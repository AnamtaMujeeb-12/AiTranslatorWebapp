# %% [markdown]
# <a href="https://colab.research.google.com/github/AnamtaMujeeb-12/AiTranslatorWebapp/blob/main/Speechtotext.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai-whisper
# !apt install -y ffmpeg # support audio message

import whisper
from google.colab import files

model = whisper.load_model("base")

uploaded = files.upload()
audio = list(uploaded.keys())[0]

result = model.transcribe(audio, fp16=False)
#fp16 = freq rate for bits
print(result["text"])
